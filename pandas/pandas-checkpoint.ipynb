# %%
import pandas as pd

# %%
df = pd.read_csv('https://raw.githubusercontent.com/raveendran2862/dataset/refs/heads/main/marketing_customer_data_uncleaned.csv',skiprows = 3)
df
# Out:
#            ID  Year_Birth        Education Marital_Status  Unnamed: 4  \
# 0      1826.0      1970.0       Graduation       Divorced         NaN
# 1         1.0      1961.0       Graduation         Single         NaN
# 2         1.0      1961.0       Graduation         Single         NaN
# 3     10476.0      1958.0       Graduation        Married         NaN
# 4         NaN         NaN              NaN            NaN         NaN
# ...       ...         ...              ...            ...         ...
# 2240  10142.0      1976.0              PhD       Divorced         NaN
# 2241   5263.0      1977.0  Bachelor degree        Married         NaN
# 2242     22.0      1976.0       Graduation       Divorced         NaN
# 2243    528.0      1978.0       Graduation        Married         NaN
# 2244   4070.0      1969.0              PhD        Married         NaN
#
#           Income    Kidhome  Teenhome Dt_Customer Country  Complain  \
# ...

# %%
df.columns   ## to view the column names
# Out:
# Index(['ID', 'Year_Birth', 'Education', 'Marital_Status', 'Unnamed: 4',
#        ' Income ', 'Kidhome', 'Teenhome', 'Dt_Customer', 'Country', 'Complain',
#        'Successful Campaigns'],
#       dtype='object')

# %%
df.shape
# Out:
# (2245, 12)

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2245 entries, 0 to 2244
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   ID                    2242 non-null   float64
#  1   Year_Birth            2242 non-null   float64
#  2   Education             2242 non-null   object
#  3   Marital_Status        2242 non-null   object
#  4   Unnamed: 4            0 non-null      float64
#  5    Income               2218 non-null   object
#  6   Kidhome               2242 non-null   object
#  7   Teenhome              2242 non-null   float64
#  8   Dt_Customer           2242 non-null   object
#  9   Country               2242 non-null   object
#  10  Complain              2242 non-null   float64
#  11  Successful Campaigns  2242 non-null   float64
# dtypes: float64(6), object(6)
# memory usage: 210.6+ KB

# %%
df.head(7)   ### 1st 5 rows by default
# Out:
#         ID  Year_Birth   Education Marital_Status  Unnamed: 4      Income   \
# 0   1826.0      1970.0  Graduation       Divorced         NaN  $84,835.00
# 1      1.0      1961.0  Graduation         Single         NaN  $57,091.00
# 2      1.0      1961.0  Graduation         Single         NaN  $57,091.00
# 3  10476.0      1958.0  Graduation        Married         NaN  $67,267.00
# 4      NaN         NaN         NaN            NaN         NaN          NaN
# 5   1386.0      1967.0  Graduation       Together         NaN  $32,474.00
# 6   5371.0      1989.0  Graduation         Single         NaN  $21,474.00
#
#     Kidhome  Teenhome Dt_Customer Country  Complain  Successful Campaigns
# 0  0 kid(s)       0.0   6/16/2014      SP       0.0                   1.0
# 1  0 kid(s)       0.0   6/15/2014      CA       0.0                   1.0
# 2  0 kid(s)       0.0   6/15/2014      CA       0.0                   1.0
# 3  0 kid(s)       1.0   5/13/2014      US       0.0                   0.0
# ...

# %%
df.tail()  ## last 5 rows by default
# Out:
#            ID  Year_Birth        Education Marital_Status  Unnamed: 4  \
# 2240  10142.0      1976.0              PhD       Divorced         NaN
# 2241   5263.0      1977.0  Bachelor degree        Married         NaN
# 2242     22.0      1976.0       Graduation       Divorced         NaN
# 2243    528.0      1978.0       Graduation        Married         NaN
# 2244   4070.0      1969.0              PhD        Married         NaN
#
#           Income    Kidhome  Teenhome Dt_Customer Country  Complain  \
# 2240  $66,476.00   0 kid(s)       1.0  03-07-2013      US       0.0
# 2241  $31,056.00   1 kid(s)       0.0   1/22/2013      SP       0.0
# 2242  $46,310.00   1 kid(s)       0.0  12-03-2012      SP       0.0
# 2243  $65,819.00   0 kid(s)       0.0  11/29/2012     IND       0.0
# 2244  $94,871.00   0 kid(s)       2.0  09-01-2012      CA       0.0
#
#       Successful Campaigns
# 2240                   0.0
# 2241                   0.0
# 2242                   0.0
# ...

# %%
df.sample(5)  ### it gives random rows by default 1
# Out:
#           ID  Year_Birth   Education Marital_Status  Unnamed: 4      Income   \
# 26     115.0      1966.0      Master         Single         NaN  $43,456.00
# 1980  2350.0      1972.0  Graduation        Married         NaN  $59,666.00
# 1466  3439.0      1972.0  Graduation        Married         NaN  $56,721.00
# 458   4415.0      1961.0  Graduation        Married         NaN  $16,860.00
# 1515   916.0      1972.0         PhD         Single         NaN  $41,644.00
#
#        Kidhome  Teenhome Dt_Customer Country  Complain  Successful Campaigns
# 26    0 kid(s)       1.0   3/26/2013     IND       0.0                   0.0
# 1980  1 kid(s)       1.0   3/22/2013      CA       0.0                   0.0
# 1466  1 kid(s)       1.0  10/31/2012      SP       0.0                   0.0
# 458   1 kid(s)       1.0  09-12-2012      SP       0.0                   0.0
# 1515  1 kid(s)       1.0  05-09-2014      SP       0.0                   0.0

# %%
df.dtypes   ### it shows the datatype of ur col
# Out:
# ID                      float64
# Year_Birth              float64
# Education                object
# Marital_Status           object
# Unnamed: 4              float64
#  Income                  object
# Kidhome                  object
# Teenhome                float64
# Dt_Customer              object
# Country                  object
# Complain                float64
# Successful Campaigns    float64
# dtype: object

# %%
df1 = df[["Education",'Marital_Status'," Income "]]
df1.head()
# Out:
#     Education Marital_Status      Income
# 0  Graduation       Divorced  $84,835.00
# 1  Graduation         Single  $57,091.00
# 2  Graduation         Single  $57,091.00
# 3  Graduation        Married  $67,267.00
# 4         NaN            NaN          NaN

# %%
df1.Education.unique()
# Out:
# array(['Graduation', nan, 'PhD', 'Bachelor degree', 'Master',
#        'Undergraduate'], dtype=object)

# %%
df.Marital_Status.unique()
# Out:
# array(['Divorced', 'Single', 'Married', nan, 'Together', 'Widow', 'YOLO',
#        'Alone', 'Absurd'], dtype=object)

# %%
df.Marital_Status.value_counts()
# Out:
# Marital_Status
# Married     864
# Together    580
# Single      482
# Divorced    232
# Widow        77
# Alone         3
# YOLO          2
# Absurd        2
# Name: count, dtype: int64

# %%
df.columns = df.columns.str.strip().str.lower()
df.columns
# Out:
# Index(['id', 'year_birth', 'education', 'marital_status', 'unnamed: 4',
#        'income', 'kidhome', 'teenhome', 'dt_customer', 'country', 'complain',
#        'successful campaigns'],
#       dtype='object')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2245 entries, 0 to 2244
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   id                    2242 non-null   float64
#  1   year_birth            2242 non-null   float64
#  2   education             2242 non-null   object
#  3   marital_status        2242 non-null   object
#  4   unnamed: 4            0 non-null      float64
#  5   income                2218 non-null   object
#  6   kidhome               2242 non-null   object
#  7   teenhome              2242 non-null   float64
#  8   dt_customer           2242 non-null   object
#  9   country               2242 non-null   object
#  10  complain              2242 non-null   float64
#  11  successful campaigns  2242 non-null   float64
# dtypes: float64(6), object(6)
# memory usage: 210.6+ KB

# %%
df.drop("unnamed: 4",axis = 1,inplace = True)  ## inplace = True --> Ctrl + s

# %%
df.shape
# Out:
# (2245, 11)

# %%
df.duplicated().sum()   ## to check duplicates
# Out:
# np.int64(4)

# %%
df[df.duplicated()]
# Out:
#         id  year_birth   education marital_status       income   kidhome  \
# 2      1.0      1961.0  Graduation         Single  $57,091.00   0 kid(s)
# 7      NaN         NaN         NaN            NaN          NaN       NaN
# 9      NaN         NaN         NaN            NaN          NaN       NaN
# 10  7348.0      1958.0         PhD         Single  $71,691.00   0 kid(s)
#
#     teenhome dt_customer country  complain  successful campaigns
# 2        0.0   6/15/2014      CA       0.0                   1.0
# 7        NaN         NaN     NaN       NaN                   NaN
# 9        NaN         NaN     NaN       NaN                   NaN
# 10       0.0   3/17/2014      SP       0.0                   1.0

# %%
df.drop_duplicates(inplace = True)

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df.isnull().sum()
# Out:
# id                       1
# year_birth               1
# education                1
# marital_status           1
# income                  25
# kidhome                  1
# teenhome                 1
# dt_customer              1
# country                  1
# complain                 1
# successful campaigns     1
# dtype: int64

# %%
df[df.isna().any(axis =1)]
# Out:
#            id  year_birth        education marital_status income   kidhome  \
# 4         NaN         NaN              NaN            NaN    NaN       NaN
# 139    8996.0      1957.0              PhD        Married    NaN  2 kid(s)
# 267    1994.0      1983.0       Graduation        Married    NaN  1 kid(s)
# 399    3769.0      1972.0              PhD       Together    NaN  1 kid(s)
# 454    5255.0      1986.0       Graduation         Single    NaN  1 kid(s)
# 530    8268.0      1961.0              PhD        Married    NaN  0 kid(s)
# 595   10629.0      1973.0  Bachelor degree        Married    NaN  1 kid(s)
# 904   10475.0      1970.0           Master       Together    NaN  0 kid(s)
# 1002   9235.0      1957.0       Graduation         Single    NaN  1 kid(s)
# 1101   4345.0      1964.0  Bachelor degree         Single    NaN  1 kid(s)
# 1190   7187.0      1969.0           Master       Together    NaN  1 kid(s)
# ...

# %%
df.dropna(how = "all",inplace = True)

# %%
df.shape
# Out:
# (2240, 11)

# %%
df.isnull().sum()
# Out:
# id                       0
# year_birth               0
# education                0
# marital_status           0
# income                  24
# kidhome                  0
# teenhome                 0
# dt_customer              0
# country                  0
# complain                 0
# successful campaigns     0
# dtype: int64

# %%
df["income"] = df["income"].str.replace("$","")
df["income"] = df["income"].str.replace(",","").astype(float)
df.head()
# Out:
#         id  year_birth   education marital_status   income   kidhome  \
# 0   1826.0      1970.0  Graduation       Divorced  84835.0  0 kid(s)
# 1      1.0      1961.0  Graduation         Single  57091.0  0 kid(s)
# 3  10476.0      1958.0  Graduation        Married  67267.0  0 kid(s)
# 5   1386.0      1967.0  Graduation       Together  32474.0  1 kid(s)
# 6   5371.0      1989.0  Graduation         Single  21474.0  1 kid(s)
#
#    teenhome dt_customer country  complain  successful campaigns
# 0       0.0   6/16/2014      SP       0.0                   1.0
# 1       0.0   6/15/2014      CA       0.0                   1.0
# 3       1.0   5/13/2014      US       0.0                   0.0
# 5       1.0  05-11-2014     AUS       0.0                   0.0
# 6       0.0  04-08-2014      SP       0.0                   1.0

# %%
df.dtypes
# Out:
# id                      float64
# year_birth              float64
# education                object
# marital_status           object
# income                  float64
# kidhome                  object
# teenhome                float64
# dt_customer              object
# country                  object
# complain                float64
# successful campaigns    float64
# dtype: object

# %%
import seaborn as sns ## stats visuals

sns.distplot(df['income']);
# Out:
# /tmp/ipykernel_1126/2823610965.py:3: UserWarning:
#
# `distplot` is a deprecated function and will be removed in seaborn v0.14.0.
#
# Please adapt your code to use either `displot` (a figure-level function with
# similar flexibility) or `histplot` (an axes-level function for histograms).
#
# For a guide to updating your code to use the new functions, please see
# https://gist.github.com/mwaskom/de44147ed2974457ad6372750bbe5751
#
#   sns.distplot(df['income']);

# %%
df["income"].fillna(df["income"].median(),inplace = True)
# Out:
# /tmp/ipykernel_1126/182018687.py:1: FutureWarning: A value is trying to be set on a copy of a DataFrame or Series through chained assignment using an inplace method.
# The behavior will change in pandas 3.0. This inplace method will never work because the intermediate object on which we are setting values always behaves as a copy.
#
# For example, when doing 'df[col].method(value, inplace=True)', try using 'df.method({col: value}, inplace=True)' or df[col] = df[col].method(value) instead, to perform the operation inplace on the original object.
#
#
#   df["income"].fillna(df["income"].median(),inplace = True)

# %%
df.isna().sum()
# Out:
# id                      0
# year_birth              0
# education               0
# marital_status          0
# income                  0
# kidhome                 0
# teenhome                0
# dt_customer             0
# country                 0
# complain                0
# successful campaigns    0
# dtype: int64

# %%
df["marital_status"].unique()
# Out:
# array(['Single', 'Married'], dtype=object)

# %%
df["marital_status"] = df["marital_status"].map({'Single':'Single','Divorced':"Single","Widow":"Single","Married":"Married",'YOLO':"Single",
       'Alone':'Single', 'Absurd':"Single",'Together':'Married'})

# %%
df["marital_status"].value_counts()
# Out:
# marital_status
# Married    1444
# Single      796
# Name: count, dtype: int64

# %%
1444+796
# Out:
# 2240
