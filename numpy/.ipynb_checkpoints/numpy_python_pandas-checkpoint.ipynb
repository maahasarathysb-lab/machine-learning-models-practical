# %%
import numpy as np
import pandas as pd
# NumPy warm-up

a = np.array([10,20,30,40,50,60])
print(a.mean())
# Out:
# 35.0

# %%
print(a.std())
# Out:
# 17.07825127659933

# %%
print(a.reshape(-1,1).shape)
# Out:
# (6, 1)

# %%
# Pandas warm-up

df = pd.DataFrame({
    "city":["coimbatore","chennai","madurai","chennai"],
    "price":[1020,200,150,200]
})

# %%
print(df.groupby("city")["price"].mean())
# Out:
# city
# chennai        200.0
# coimbatore    1020.0
# madurai        150.0
# Name: price, dtype: float64

# %%
df[df["price"]>120]
# Out:
#          city  price
# 0  coimbatore   1020
# 1     chennai    200
# 2     madurai    150
# 3     chennai    200
